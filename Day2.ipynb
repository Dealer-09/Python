# %%
lst=[]
print(type(lst))
# Out:
# <class 'list'>

# %%
list=["Archis","Ayush","Vikash",1,2,3,True]
print(list)
# Out:
# ['Archis', 'Ayush', 'Vikash', 1, 2, 3, True]

# %%
name=["Archis","Ayush","Vikash","Anway"]
print(name[1])
print(name[-1])
print(name[1:3])
# Out:
# Ayush
# Anway
# ['Ayush', 'Vikash']

# %%
name[1]="Ayan"
print(name)
name[1:]="Archisman"
print(name)
# Out:
# ['Archis', 'Ayan', 'Vikash', 'Anway']
# ['Archis', 'A', 'r', 'c', 'h', 'i', 's', 'm', 'a', 'n']

# %%
#Append 
name=["Archis","Ayush","Vikash","Anway"]
name.append("Ayan")
print(name)

#Insert
name.insert(1,"Raj")
print(name)

#Remove first occurence of an item
name.remove("Ayan")
print(name)
# Out:
# ['Archis', 'Ayush', 'Vikash', 'Anway', 'Ayan']
# ['Archis', 'Raj', 'Ayush', 'Vikash', 'Anway', 'Ayan']
# ['Archis', 'Raj', 'Ayush', 'Vikash', 'Anway']

# %%
#Pop
popped=name.pop()
print(name)
print(popped)
# Out:
# ['Archis', 'Raj', 'Ayush', 'Vikash']
# Anway

# %%
#Index
index=name.index("Vikash")
print(index)
# Out:
# 3

# %%
name.insert(2,"Ayush")
print(name)

# Count
print(name.count("Ayush"))
# Out:
# ['Archis', 'Raj', 'Ayush', 'Ayush', 'Vikash']
# 2
